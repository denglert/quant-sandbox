# %%
import os
setup_script = os.path.join(os.environ['ENV_JUPYTER_SETUPS_DIR'], 'setup_sci_env_basic.py')
# %run $setup_script
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
load_mpl_style('single_plot.mplstyle')
ignore_warnings()

# %%
from pandas_datareader import data as web
import datetime as dt
import time
import bs4 as bs
import pickle
import csv
import requests
import os

# %%
def save_spx_tickers(tickers_out="spx_tickers.dat"):
    spx_wiki_url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    resp = requests.get(spx_wiki_url)
    soup = bs.BeautifulSoup(resp.text)
    table = soup.find('table', {'class':'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        tickers.append(ticker)
    
    with open(tickers_out, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(tickers)
        
    return tickers

# %%
tickers = save_spx_tickers()

# %%
def get_all_tickers(reload_tickers=False,
                    tickers_list="spx_tickers.dat",
                    start = dt.datetime(2017,1,1),
                    end = dt.datetime(2018,2,20),
                    datareader_pause=1
                   ):
    
    if reload_tickers:
        tickers = save_spx_tickers()
    else:
        with open(tickers_list, 'r') as f:
            reader = csv.reader(f)
            tickers = next(reader)
    
    for ticker in tickers:
        ticker_data_path = "spx_data/{}.dat".format(ticker)
        if not os.path.exists(ticker_data_path):
            
            try:
                df = web.DataReader(ticker, 'yahoo', start, end)
            except:
                pass
            time.sleep(datareader_pause)
            df.to_csv(ticker_data_path)
            msg = "{} downloaded.".format(ticker)
            print(msg)
        else:
            msg = "{} already retrieved.".format(ticker)
            print(msg)

# %%
get_all_tickers()
# Out:
# MMM already retrieved.
# ABT already retrieved.
# ABBV already retrieved.
# ACN already retrieved.
# ATVI already retrieved.
# AYI already retrieved.
# ADBE already retrieved.
# AMD already retrieved.
# AAP already retrieved.
# AES already retrieved.
# AET already retrieved.
# AMG already retrieved.
# AFL already retrieved.
# A already retrieved.
# APD already retrieved.
# AKAM already retrieved.
# ALK already retrieved.
# ALB already retrieved.
# ARE already retrieved.
# ALXN already retrieved.
# ALGN already retrieved.
# ALLE already retrieved.
# AGN already retrieved.
# ADS already retrieved.
# LNT already retrieved.
# ALL already retrieved.
# GOOGL already retrieved.
# GOOG already retrieved.
# MO already retrieved.
# AMZN already retrieved.
# AEE already retrieved.
# AAL already retrieved.
# AEP already retrieved.
# AXP already retrieved.
# AIG already retrieved.
# AMT already retrieved.
# AWK already retrieved.
# AMP already retrieved.
# ABC already retrieved.
# AME already retrieved.
# AMGN already retrieved.
# APH already retrieved.
# APC already retrieved.
# ADI already retrieved.
# ANDV already retrieved.
# ANSS already retrieved.
# ANTM already retrieved.
# AON already retrieved.
# AOS already retrieved.
# APA already retrieved.
# AIV already retrieved.
# AAPL already retrieved.
# AMAT already retrieved.
# APTV already retrieved.
# ADM already retrieved.
# ARNC already retrieved.
# AJG already retrieved.
# AIZ already retrieved.
# T already retrieved.
# ADSK already retrieved.
# ADP already retrieved.
# AZO already retrieved.
# AVB already retrieved.
# AVY already retrieved.
# BHGE already retrieved.
# BLL already retrieved.
# BAC already retrieved.
# BK already retrieved.
# BAX already retrieved.
# BBT already retrieved.
# BDX already retrieved.
# BRK.B already retrieved.
# BBY already retrieved.
# BIIB already retrieved.
# BLK already retrieved.
# HRB already retrieved.
# BA already retrieved.
# BWA already retrieved.
# BXP already retrieved.
# BSX already retrieved.
# BHF already retrieved.
# BMY already retrieved.
# AVGO already retrieved.
# BF.B already retrieved.
# CHRW already retrieved.
# CA already retrieved.
# COG already retrieved.
# CDNS already retrieved.
# CPB already retrieved.
# COF already retrieved.
# CAH already retrieved.
# CBOE already retrieved.
# KMX already retrieved.
# CCL already retrieved.
# CAT already retrieved.
# CBG already retrieved.
# CBS already retrieved.
# CELG already retrieved.
# CNC already retrieved.
# CNP already retrieved.
# CTL already retrieved.
# CERN already retrieved.
# CF already retrieved.
# SCHW already retrieved.
# CHTR already retrieved.
# CHK already retrieved.
# CVX already retrieved.
# CMG already retrieved.
# CB already retrieved.
# CHD already retrieved.
# CI already retrieved.
# XEC already retrieved.
# CINF already retrieved.
# CTAS already retrieved.
# CSCO already retrieved.
# C already retrieved.
# CFG already retrieved.
# CTXS already retrieved.
# CLX already retrieved.
# CME already retrieved.
# CMS already retrieved.
# KO already retrieved.
# CTSH already retrieved.
# CL already retrieved.
# CMCSA already retrieved.
# CMA already retrieved.
# CAG already retrieved.
# CXO already retrieved.
# COP already retrieved.
# ED already retrieved.
# STZ already retrieved.
# COO already retrieved.
# GLW already retrieved.
# COST already retrieved.
# COTY already retrieved.
# CCI already retrieved.
# CSRA already retrieved.
# CSX already retrieved.
# CMI already retrieved.
# CVS already retrieved.
# DHI already retrieved.
# DHR already retrieved.
# DRI already retrieved.
# DVA already retrieved.
# DE already retrieved.
# DAL already retrieved.
# XRAY already retrieved.
# DVN already retrieved.
# DLR already retrieved.
# DFS already retrieved.
# DISCA already retrieved.
# DISCK already retrieved.
# DISH already retrieved.
# DG already retrieved.
# DLTR already retrieved.
# D already retrieved.
# DOV already retrieved.
# DWDP already retrieved.
# DPS already retrieved.
# DTE already retrieved.
# DRE already retrieved.
# DUK already retrieved.
# DXC already retrieved.
# ETFC already retrieved.
# EMN already retrieved.
# ETN already retrieved.
# EBAY already retrieved.
# ECL already retrieved.
# EIX already retrieved.
# EW already retrieved.
# EA already retrieved.
# EMR already retrieved.
# ETR already retrieved.
# EVHC already retrieved.
# EOG already retrieved.
# EQT already retrieved.
# EFX already retrieved.
# EQIX already retrieved.
# EQR already retrieved.
# ESS already retrieved.
# EL already retrieved.
# ES already retrieved.
# RE already retrieved.
# EXC already retrieved.
# EXPE already retrieved.
# EXPD already retrieved.
# ESRX already retrieved.
# EXR already retrieved.
# XOM already retrieved.
# FFIV already retrieved.
# FB already retrieved.
# FAST already retrieved.
# FRT already retrieved.
# FDX already retrieved.
# FIS already retrieved.
# FITB already retrieved.
# FE already retrieved.
# FISV already retrieved.
# FLIR already retrieved.
# FLS already retrieved.
# FLR already retrieved.
# FMC already retrieved.
# FL already retrieved.
# F already retrieved.
# FTV already retrieved.
# FBHS already retrieved.
# BEN already retrieved.
# FCX already retrieved.
# GPS already retrieved.
# GRMN already retrieved.
# IT already retrieved.
# GD already retrieved.
# GE already retrieved.
# GGP already retrieved.
# GIS already retrieved.
# GM already retrieved.
# GPC already retrieved.
# GILD already retrieved.
# GPN already retrieved.
# GS already retrieved.
# GT already retrieved.
# GWW already retrieved.
# HAL already retrieved.
# HBI already retrieved.
# HOG already retrieved.
# HRS already retrieved.
# HIG already retrieved.
# HAS already retrieved.
# HCA already retrieved.
# HCP already retrieved.
# HP already retrieved.
# HSIC already retrieved.
# HSY already retrieved.
# HES already retrieved.
# HPE already retrieved.
# HLT already retrieved.
# HOLX already retrieved.
# HD already retrieved.
# HON already retrieved.
# HRL already retrieved.
# HST already retrieved.
# HPQ already retrieved.
# HUM already retrieved.
# HBAN already retrieved.
# HII already retrieved.
# IDXX already retrieved.
# INFO already retrieved.
# ITW already retrieved.
# ILMN already retrieved.
# IR already retrieved.
# INTC already retrieved.
# ICE already retrieved.
# IBM already retrieved.
# INCY already retrieved.
# IP already retrieved.
# IPG already retrieved.
# IFF already retrieved.
# INTU already retrieved.
# ISRG already retrieved.
# IVZ already retrieved.
# IQV already retrieved.
# IRM already retrieved.
# JEC already retrieved.
# JBHT already retrieved.
# SJM already retrieved.
# JNJ already retrieved.
# JCI already retrieved.
# JPM already retrieved.
# JNPR already retrieved.
# KSU already retrieved.
# K already retrieved.
# KEY already retrieved.
# KMB already retrieved.
# KIM already retrieved.
# KMI already retrieved.
# KLAC already retrieved.
# KSS already retrieved.
# KHC already retrieved.
# KR already retrieved.
# LB already retrieved.
# LLL already retrieved.
# LH already retrieved.
# LRCX already retrieved.
# LEG already retrieved.
# LEN already retrieved.
# LUK already retrieved.
# LLY already retrieved.
# LNC already retrieved.
# LKQ already retrieved.
# LMT already retrieved.
# L already retrieved.
# LOW already retrieved.
# LYB already retrieved.
# MTB already retrieved.
# MAC already retrieved.
# M already retrieved.
# MRO already retrieved.
# MPC already retrieved.
# MAR already retrieved.
# MMC already retrieved.
# MLM already retrieved.
# MAS already retrieved.
# MA already retrieved.
# MAT already retrieved.
# MKC already retrieved.
# MCD already retrieved.
# MCK already retrieved.
# MDT already retrieved.
# MRK already retrieved.
# MET already retrieved.
# MTD already retrieved.
# MGM already retrieved.
# KORS already retrieved.
# MCHP already retrieved.
# MU already retrieved.
# MSFT already retrieved.
# MAA already retrieved.
# MHK already retrieved.
# TAP already retrieved.
# MDLZ already retrieved.
# MON already retrieved.
# MNST already retrieved.
# MCO already retrieved.
# MS already retrieved.
# MOS already retrieved.
# MSI already retrieved.
# MYL already retrieved.
# NDAQ already retrieved.
# NOV already retrieved.
# NAVI already retrieved.
# NTAP already retrieved.
# NFLX already retrieved.
# NWL already retrieved.
# NFX already retrieved.
# NEM already retrieved.
# NWSA already retrieved.
# NWS already retrieved.
# NEE already retrieved.
# NLSN already retrieved.
# NKE already retrieved.
# NI already retrieved.
# NBL already retrieved.
# JWN already retrieved.
# NSC already retrieved.
# NTRS already retrieved.
# NOC already retrieved.
# NCLH already retrieved.
# NRG already retrieved.
# NUE already retrieved.
# NVDA already retrieved.
# ORLY already retrieved.
# OXY already retrieved.
# OMC already retrieved.
# OKE already retrieved.
# ORCL already retrieved.
# PCAR already retrieved.
# PKG already retrieved.
# PH already retrieved.
# PDCO already retrieved.
# PAYX already retrieved.
# PYPL already retrieved.
# PNR already retrieved.
# PBCT already retrieved.
# PEP already retrieved.
# PKI already retrieved.
# PRGO already retrieved.
# PFE already retrieved.
# PCG already retrieved.
# PM already retrieved.
# PSX already retrieved.
# PNW already retrieved.
# PXD already retrieved.
# PNC already retrieved.
# RL already retrieved.
# PPG already retrieved.
# PPL already retrieved.
# PX already retrieved.
# PCLN already retrieved.
# PFG already retrieved.
# PG already retrieved.
# PGR already retrieved.
# PLD already retrieved.
# PRU already retrieved.
# PEG already retrieved.
# PSA already retrieved.
# PHM already retrieved.
# PVH already retrieved.
# QRVO already retrieved.
# PWR already retrieved.
# QCOM already retrieved.
# DGX already retrieved.
# RRC already retrieved.
# RJF already retrieved.
# RTN already retrieved.
# O already retrieved.
# RHT already retrieved.
# REG already retrieved.
# REGN already retrieved.
# RF already retrieved.
# RSG already retrieved.
# RMD already retrieved.
# RHI already retrieved.
# ROK already retrieved.
# COL already retrieved.
# ROP already retrieved.
# ROST already retrieved.
# RCL already retrieved.
# CRM already retrieved.
# SBAC already retrieved.
# SCG already retrieved.
# SLB already retrieved.
# SNI already retrieved.
# STX already retrieved.
# SEE already retrieved.
# SRE already retrieved.
# SHW already retrieved.
# SIG already retrieved.
# SPG already retrieved.
# SWKS already retrieved.
# SLG already retrieved.
# SNA already retrieved.
# SO already retrieved.
# LUV already retrieved.
# SPGI already retrieved.
# SWK already retrieved.
# SBUX already retrieved.
# STT already retrieved.
# SRCL already retrieved.
# SYK already retrieved.
# STI already retrieved.
# SYMC already retrieved.
# SYF already retrieved.
# SNPS already retrieved.
# SYY already retrieved.
# TROW already retrieved.
# TPR already retrieved.
# TGT already retrieved.
# TEL already retrieved.
# FTI already retrieved.
# TXN already retrieved.
# TXT already retrieved.
# TMO already retrieved.
# TIF already retrieved.
# TWX already retrieved.
# TJX already retrieved.
# TMK already retrieved.
# TSS already retrieved.
# TSCO already retrieved.
# TDG already retrieved.
# TRV already retrieved.
# TRIP already retrieved.
# FOXA already retrieved.
# FOX already retrieved.
# TSN already retrieved.
# UDR already retrieved.
# ULTA already retrieved.
# USB already retrieved.
# UAA already retrieved.
# UA already retrieved.
# UNP already retrieved.
# UAL already retrieved.
# UNH already retrieved.
# UPS already retrieved.
# URI already retrieved.
# UTX already retrieved.
# UHS already retrieved.
# UNM already retrieved.
# VFC already retrieved.
# VLO already retrieved.
# VAR already retrieved.
# VTR already retrieved.
# VRSN already retrieved.
# VRSK already retrieved.
# VZ already retrieved.
# VRTX already retrieved.
# VIAB already retrieved.
# V already retrieved.
# VNO already retrieved.
# VMC already retrieved.
# WMT already retrieved.
# WBA already retrieved.
# DIS already retrieved.
# WM already retrieved.
# WAT already retrieved.
# WEC already retrieved.
# WFC already retrieved.
# HCN already retrieved.
# WDC already retrieved.
# WU already retrieved.
# WRK already retrieved.
# WY already retrieved.
# WHR already retrieved.
# WMB already retrieved.
# WLTW already retrieved.
# WYN already retrieved.
# WYNN already retrieved.
# XEL already retrieved.
# XRX already retrieved.
# XLNX already retrieved.
# XL already retrieved.
# XYL already retrieved.
# YUM already retrieved.
# ZBH already retrieved.
# ZION already retrieved.
# ZTS already retrieved.

# %%
def merge_data(merged_out_path='spx_all_adj_close.dat',
               tickers_list="spx_tickers.dat"):
    
    with open(tickers_list, 'r') as f:
        reader = csv.reader(f)
        tickers = next(reader)
    
    df_main = pd.DataFrame()
    
    for count,ticker in enumerate(tickers):
        ticker_data_path = "spx_data/{}.dat".format(ticker)
        df = pd.read_csv(ticker_data_path, index_col=0)
        
        df.rename(columns={'Adj Close':ticker}, inplace=True)
        df.drop(['Open', 'High', 'Low', 'Close', 'Volume'], 1, inplace=True)
        
        if df_main.empty:
            df_main = df
        else:
            df_main = df_main.join(df, how='outer')
        
        if count % 10 == 0:
            print(count)
    df_main.to_csv(merged_out_path)
    return df_main

# %%
#merge_data()
